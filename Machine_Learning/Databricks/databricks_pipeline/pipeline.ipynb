# %% [markdown]
# ### Load libraries

# %%
# %pip install databricks-feature-store
# Out:
# Requirement already satisfied: databricks-feature-store in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (0.17.0)
# Requirement already satisfied: databricks-feature-engineering>=0.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from databricks-feature-store) (0.15.0)
# Requirement already satisfied: mlflow-skinny<4,>=2.16.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.8.1)
# Requirement already satisfied: pyyaml<7,>=6 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (6.0.2)
# Requirement already satisfied: boto3<2,>=1.16.7 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.40.45)
# Requirement already satisfied: dbl-tempo<1,>=0.1.26 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.1.30)
# Requirement already satisfied: azure-cosmos==4.3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.3.1)
# Requirement already satisfied: numpy<3,>=1.19.2 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.1.3)
# Requirement already satisfied: protobuf<7,>=5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (5.29.6)
# Requirement already satisfied: flask<3,>=1.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.3.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.5.5)
# Requirement already satisfied: databricks-sdk<1,>=0.103.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.105.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /databricks/python3/lib/python3.12/site-packages (from azure-cosmos==4.3.1->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.37.0)
# Requirement already satisfied: botocore<1.41.0,>=1.40.45 in /databricks/python3/lib/python3.12/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.40.45)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.0.1)
# Requirement already satisfied: s3transfer<0.15.0,>=0.14.0 in /databricks/python3/lib/python3.12/site-packages (from boto3<2,>=1.16.7->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.14.0)
# Requirement already satisfied: requests<3,>=2.28.1 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.32.3)
# Requirement already satisfied: google-auth~=2.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.47.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.1.8)
# Requirement already satisfied: Jinja2>=3.1.2 in /databricks/python3/lib/python3.12/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-cf1952cb-8e1f-4b98-915f-f924d707cde6/lib/python3.12/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /databricks/python3/lib/python3.12/site-packages (from flask<3,>=1.1.2->databricks-feature-engineering>=0.2.0->databricks-feature-store) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/lib/python3/dist-packages (from flask<3,>=1.1.2->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.7.0)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (5.5.1)
# Requirement already satisfied: cloudpickle<4 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.0.0)
# Requirement already satisfied: fastapi<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.128.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.1.43)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (8.5.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.39.1)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.39.1)
# Requirement already satisfied: packaging<26 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (24.2)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.10.6)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.2.1)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.12.2)
# Requirement already satisfied: uvicorn<1 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.40.0)
# Requirement already satisfied: azure-storage-file-datalake>12 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (12.22.0)
# Requirement already satisfied: google-cloud-storage>=1.30.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.7.0)
# Requirement already satisfied: databricks-agents<2.0,>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.9.1)
# Requirement already satisfied: azure-storage-blob>=12.27.0 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (12.28.0)
# Requirement already satisfied: isodate>=0.6.1 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.7.2)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /databricks/python3/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.45->boto3<2,>=1.16.7->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /databricks/python3/lib/python3.12/site-packages (from botocore<1.41.0,>=1.40.45->boto3<2,>=1.16.7->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.3.0)
# Requirement already satisfied: dataclasses-json in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.6.7)
# Requirement already satisfied: googleapis-common-protos in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.65.0)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.2.3)
# Requirement already satisfied: tenacity>=8.5 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (9.0.0)
# Requirement already satisfied: tiktoken>=0.8.0 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.12.0)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.67.1)
# Requirement already satisfied: whenever==0.7.3 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.7.3)
# Requirement already satisfied: litellm==1.75.9 in /databricks/python3/lib/python3.12/site-packages (from databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.75.9)
# Requirement already satisfied: aiohttp>=3.10 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.11.10)
# Requirement already satisfied: httpx>=0.23.0 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.28.1)
# Requirement already satisfied: jsonschema<5.0.0,>=4.22.0 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.23.0)
# Requirement already satisfied: openai>=1.99.5 in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.14.0)
# Requirement already satisfied: tokenizers in /databricks/python3/lib/python3.12/site-packages (from litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.22.2)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /databricks/python3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /databricks/python3/lib/python3.12/site-packages (from fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.0.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /databricks/python3/lib/python3.12/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.9.1)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.28.1)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.5.0)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.8.0)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /databricks/python3/lib/python3.12/site-packages (from google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.8.0)
# Requirement already satisfied: zipp>=3.20 in /databricks/python3/lib/python3.12/site-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from Jinja2>=3.1.2->flask<3,>=1.1.2->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.0.2)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in /databricks/python3/lib/python3.12/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.60b1)
# Requirement already satisfied: annotated-types>=0.6.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2.0.0->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests<3,>=2.28.1->databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2025.4.26)
# Requirement already satisfied: h11>=0.8 in /databricks/python3/lib/python3.12/site-packages (from uvicorn<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.16.0)
# Requirement already satisfied: cryptography>=2.1.4 in /databricks/python3/lib/python3.12/site-packages (from azure-storage-blob>=12.27.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (44.0.1)
# Requirement already satisfied: langchain-openai in /databricks/python3/lib/python3.12/site-packages (from databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.1.6)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (5.0.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /databricks/python3/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage>=1.30.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.27.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /databricks/python3/lib/python3.12/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.103.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.4.8)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.41.0,>=1.40.45->boto3<2,>=1.16.7->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.17.0)
# Requirement already satisfied: anyio<5,>=3.6.2 in /databricks/python3/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (4.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /databricks/python3/lib/python3.12/site-packages (from tiktoken>=0.8.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2024.11.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /databricks/python3/lib/python3.12/site-packages (from dataclasses-json->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from dataclasses-json->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.9.0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /databricks/python3/lib/python3.12/site-packages (from aiohttp>=3.10->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.18.0)
# Requirement already satisfied: sniffio>=1.1 in /databricks/python3/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny<4,>=2.16.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.3.0)
# Requirement already satisfied: cffi>=1.12 in /databricks/python3/lib/python3.12/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.27.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.17.1)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.12/site-packages (from httpx>=0.23.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.0.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /databricks/python3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /databricks/python3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /databricks/python3/lib/python3.12/site-packages (from jsonschema<5.0.0,>=4.22.0->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.22.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai>=1.99.5->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /databricks/python3/lib/python3.12/site-packages (from openai>=1.99.5->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.12.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.0.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.2 in /databricks/python3/lib/python3.12/site-packages (from langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.2.6)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /databricks/python3/lib/python3.12/site-packages (from tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.2.4)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.12/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.27.0->azure-storage-file-datalake>12->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2.21)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (2023.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.2.0)
# Requirement already satisfied: shellingham in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.5.4)
# Requirement already satisfied: typer-slim in /databricks/python3/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers->litellm==1.75.9->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.21.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /databricks/python3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /databricks/python3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.6.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /databricks/python3/lib/python3.12/site-packages (from langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /databricks/python3/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /databricks/python3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /databricks/python3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /databricks/python3/lib/python3.12/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.2->langchain-openai->databricks-sdk[openai]>=0.58.0->databricks-agents<2.0,>=1.2.0->mlflow-skinny[databricks]<4,>=2.16.0->databricks-feature-engineering>=0.2.0->databricks-feature-store) (0.23.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ### Define catalog as object

# %%
# Definice tvé struktury v Unity Catalogu
catalog_name = "workspace"  # Tvůj zjištěný katalog
schema_name = "default"    # Tvé schéma (pískoviště)

# Pokud chceš používat tu zkratku DA (jako v kurzech), udělej tohle:
class DA:
    catalog_name = "workspace"
    schema_name = "default"

print(DA.catalog_name)
print(DA.schema_name)
# Out:
# workspace
# default

# %% [markdown]
# ### Load data

# %%
# Načtení tabulky přímo z katalogu
df_bronze = spark.table("workspace.default.input")

# Zobrazení dat
display(df_bronze)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>name</th><th>age</th><th>education</th><th>experience</th><th>department</th><th>is_manager</th><th>country</th><th>gender</th><th>salary</th><th>hobby</th></tr></thead><tbody><tr><td>id_001</td><td>John</td><td>28</td><td>Bachelor</td><td>6</td><td>IT</td><td>0</td><td>USA</td><td>Male</td><td>65000</td><td>null</td></tr><tr><td>id_002</td><td>Alice</td><td>45</td><td>Master</td><td>21</td><td>Sales</td><td>1</td><td>Germany</td><td>Female</td><td>115000</td><td>null</td></tr><tr><td>id_003</td><td>Martin</td><td>null</td><td>Secondary</td><td>5</td><td>HR</td><td>0</td><td>Czechia</td><td>Male</td><td>38000</td><td>null</td></tr><tr><td>id_004</td><td>Chris</td><td>55</td><td>PhD</td><td>28</td><td>IT</td><td>1</td><td>USA</td><td>Male</td><td>145000</td><td>null</td></tr><tr><td>id_005</td><td>Emma</td><td>31</td><td>Bachelor</td><td>9</td><td>Marketing</td><td>0</td><td>Germany</td><td>Female</td><td>62000</td><td>null</td></tr><tr><td>id_006</td><td>Liam</td><td>25</td><td>Secondary</td><td>7</td><td>Sales</td><td>0</td><td>USA</td><td>Male</td><td>46000</td><td>null</td></tr><tr><td>id_006</td><td>Liam</td><td>25</td><td>Secondary</td><td>7</td><td>Sales</td><td>0</td><td>USA</td><td>Male</td><td>46000</td><td>null</td></tr><tr><td>id_007</td><td>Olivia</td><td>42</td><td>Master</td><td>18</td><td>IT</td><td>0</td><td>Germany</td><td>Female</td><td>98000</td><td>null</td></tr><tr><td>id_008</td><td>Noah</td><td>60</td><td>PhD</td><td>33</td><td>Sales</td><td>1</td><td>Czechia</td><td>Male</td><td>155000</td><td>null</td></tr><tr><td>id_009</td><td>Sophia</td><td>29</td><td>Bachelor</td><td>7</td><td>HR</td><td>0</td><td>Czechia</td><td>Female</td><td>55000</td><td>books</td></tr><tr><td>id_010</td><td>James</td><td>48</td><td>Master</td><td>24</td><td>Marketing</td><td>1</td><td>USA</td><td>Male</td><td>120000</td><td>null</td></tr><tr><td>id_011</td><td>Mia</td><td>22</td><td>Primary</td><td>4</td><td>IT</td><td>0</td><td>Germany</td><td>Female</td><td>32000</td><td>null</td></tr><tr><td>id_012</td><td>Lucas</td><td>53</td><td>PhD</td><td>26</td><td>Sales</td><td>1</td><td>Germany</td><td>Male</td><td>138000</td><td>null</td></tr><tr><td>id_013</td><td>Charlotte</td><td>null</td><td>Bachelor</td><td>11</td><td>HR</td><td>0</td><td>USA</td><td>Female</td><td>64000</td><td>null</td></tr><tr><td>id_014</td><td>Mason</td><td>24</td><td>Secondary</td><td>6</td><td>Marketing</td><td>0</td><td>Czechia</td><td>Male</td><td>41000</td><td>null</td></tr><tr><td>id_015</td><td>Amelia</td><td>44</td><td>Master</td><td>20</td><td>IT</td><td>1</td><td>USA</td><td>Female</td><td>180000</td><td>null</td></tr><tr><td>id_016</td><td>Ethan</td><td>57</td><td>PhD</td><td>30</td><td>Sales</td><td>1</td><td>Germany</td><td>Male</td><td>150000</td><td>null</td></tr><tr><td>id_017</td><td>Harper</td><td>30</td><td>Bachelor</td><td>8</td><td>HR</td><td>0</td><td>Germany</td><td>Female</td><td>59000</td><td>null</td></tr><tr><td>id_017</td><td>Harper</td><td>30</td><td>Bachelor</td><td>8</td><td>HR</td><td>0</td><td>Germany</td><td>Female</td><td>59000</td><td>null</td></tr><tr><td>id_018</td><td>Logan</td><td>26</td><td>Secondary</td><td>8</td><td>Marketing</td><td>0</td><td>USA</td><td>Male</td><td>49000</td><td>null</td></tr><tr><td>id_019</td><td>Ava</td><td>43</td><td>Master</td><td>19</td><td>IT</td><td>0</td><td>Czechia</td><td>Female</td><td>92000</td><td>null</td></tr><tr><td>id_020</td><td>Alexander</td><td>59</td><td>PhD</td><td>32</td><td>Sales</td><td>1</td><td>USA</td><td>Male</td><td>148000</td><td>null</td></tr><tr><td>id_021</td><td>Isabella</td><td>35</td><td>Bachelor</td><td>13</td><td>Marketing</td><td>0</td><td>Germany</td><td>Female</td><td>71000</td><td>null</td></tr><tr><td>id_022</td><td>Daniel</td><td>40</td><td>Master</td><td>16</td><td>IT</td><td>0</td><td>Germany</td><td>Male</td><td>88000< ...
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ###Data types

# %%
df_bronze.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- education: string (nullable = true)
#  |-- experience: long (nullable = true)
#  |-- department: string (nullable = true)
#  |-- is_manager: long (nullable = true)
#  |-- country: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- hobby: string (nullable = true)

# %%
from pyspark.sql.functions import col

# Takhle změníš typy u konkrétních sloupců
df_bronze = (df_bronze.withColumn("age", col("age").cast("int"))
            .withColumn("salary", col("salary").cast("double"))
            .withColumn("experience", col("experience").cast("int"))
            .withColumn("is_manager", col("is_manager").cast("int"))
)

# Kontrola
df_bronze.printSchema()
# Out:
# root
#  |-- id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- education: string (nullable = true)
#  |-- experience: integer (nullable = true)
#  |-- department: string (nullable = true)
#  |-- is_manager: integer (nullable = true)
#  |-- country: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: double (nullable = true)
#  |-- hobby: string (nullable = true)

# %% [markdown]
# ### Drop duplicates

# %%
# Odstraníme duplikáty
df_gold = df_bronze.dropDuplicates()

# Spočítáme řádky před
count_before = df_bronze.count()

# Spočítáme řádky po
count_after = df_gold.count()

print(f"Odstraněno {count_before - count_after} úplných duplikátů.")
# Out:
# Odstraněno 2 úplných duplikátů.

# %% [markdown]
# ### Check NaN

# %%
from pyspark.sql.functions import col, when, count, lit, round

# 1. Spočítáme celkový počet řádků
total_rows = df_gold.count()

# 2. Spočítáme NULLy pro každý sloupec
null_counts = df_gold.select([
    count(when(col(c).isNull(), c)).alias(c) 
    for c in df_gold.columns
])

# 3. Převedeme sloupce na řádky (unpivot) a dopočítáme procenta
# Použijeme stack, abychom dostali název sloupce a jeho počet nulls pod sebe
stack_expr = ", ".join([f"'{c}', `{c}`" for c in df_bronze.columns])

missing_df = null_counts.selectExpr(f"stack({len(df_gold.columns)}, {stack_expr}) as (column_name, null_count)") \
    .withColumn("percentage_nan", round((col("null_count") / total_rows) * 100, 2)) \
    .select("column_name", "percentage_nan")

missing_df.show(truncate=False)
# Out:
# +-----------+--------------+
# |column_name|percentage_nan|
# +-----------+--------------+
# |id         |0.0           |
# |name       |0.0           |
# |age        |13.33         |
# |education  |0.0           |
# |experience |0.0           |
# |department |0.0           |
# |is_manager |0.0           |
# |country    |0.0           |
# |gender     |0.0           |
# |salary     |0.0           |
# |hobby      |93.33         |
# +-----------+--------------+

# %%
# Vyfiltrujeme sloupce s více než 60 % NaN a uložíme jejich názvy do seznamu
cols_to_drop = [row['column_name'] for row in missing_df.filter(col("percentage_nan") > 60).collect()]

print(f"Sloupce k odstranění (> 60% NaN): {cols_to_drop}")
# Out:
# Sloupce k odstranění (> 60% NaN): ['hobby']

# %%
# Odstranění sloupců z tvého hlavního DataFrame
print(f"Původní počet sloupců: {len(df_gold.columns)}")

df_gold = df_gold.drop(*cols_to_drop)

print(f"Nový počet sloupců: {len(df_gold.columns)}")
# Out:
# Původní počet sloupců: 11
# Nový počet sloupců: 10

# %% [markdown]
# ### Save golden table into Feature Store

# %%
from databricks.feature_store import FeatureStoreClient
fs = FeatureStoreClient()

# %%
# show available catalogs
display(spark.sql("SHOW CATALOGS"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>samples</td></tr><tr><td>system</td></tr><tr><td>workspace</td></tr></tbody></table></div>

# %%
# Definuj název (v Unity Catalogu: catalog.schema.table_name)
feature_table_name = "workspace.default.salary_features"

# Vytvoření tabulky ve Feature Storu
fs.create_table(
    name=feature_table_name,
    primary_keys=["id"],  # Tvoje unikátní ID
    df=df_gold,        # Tvůj vyčištěný DataFrame (bez duplikátů a NaN sloupců)
    schema=df_gold.schema,
    description="Feature table contains all important features for model training."
)
# Out:
# <FeatureTable: name='workspace.default.salary_features', table_id='cc2a8b55-8b02-42e9-914b-33730edc1dbc', description='Feature table contains all important features for model training.', primary_keys=['id'], partition_columns=[], features=['id',
#  'name',
#  'age',
#  'education',
#  'experience',
#  'department',
#  'is_manager',
#  'country',
#  'gender',
#  'salary'], creation_timestamp=1777139711557, online_stores=[], notebook_producers=[], job_producers=[], table_data_sources=[], path_data_sources=[], custom_data_sources=[], timestamp_keys=[], tags={}>

# %% [markdown]
# ### Pipeline

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import Imputer, StringIndexer, OneHotEncoder, VectorAssembler, StandardScaler
from pyspark.sql.functions import col, when
from pyspark.ml.feature import SQLTransformer

from pyspark.ml.regression import LinearRegression

# %%
# 0. Ordinální kategorická proměnná
# Definuješ SQL výraz. 
# '__THIS__' v PySparku znamená "aktuální tabulka, která zrovna protéká pipelinou"

education_mapping = SQLTransformer(statement="""
    SELECT *,
    CASE 
        WHEN education = 'Primary' THEN 1
        WHEN education = 'Secondary' THEN 2
        WHEN education = 'Bachelor' THEN 3
        WHEN education = 'Master' THEN 4
        WHEN education = 'PhD' THEN 5
        ELSE 0 
    END as education_num
    FROM __THIS__
""")


# 1. Imputer na čísla
imputer = Imputer(
    inputCols=["age", "experience"], 
    outputCols=["age", "experience"], 
    strategy="median"
)


# 2. Indexer pro VŠECHNY kategorie (nominální i binární)
# Přidali jsme gender a is_manager, aby se s nimi Pipeline poprala sama
indexer = StringIndexer(
    inputCols=["country", "department", "gender"], 
    outputCols=["country_idx", "dept_idx", "gender_idx"],
    handleInvalid="keep"
)

# 3. OHE jen pro ty s více kategoriemi (Country, Dept)
ohe = OneHotEncoder(
    inputCols=["country_idx", "dept_idx", "gender_idx", "is_manager"], 
    outputCols=["country_ohe", "dept_ohe", "gender_ohe", "is_manager_ohe"],
    dropLast=True
)

# 4. Assembler - teď bere všechno dohromady
assembler = VectorAssembler(
    inputCols=[
        "age", 
        "experience", 
        "education_num", 
        "gender_ohe",  # OHE vektory
        "is_manager_ohe", # OHE vektory
        "country_ohe", # OHE vektory
        "dept_ohe"     # OHE vektory
    ], 
    outputCol="unscaled_features"
)

# 5. Scaler - Finální úprava měřítka
scaler = StandardScaler(inputCol="unscaled_features", outputCol="scaled_features")


# 6. Model
model = LinearRegression(
    featuresCol="scaled_features", 
    labelCol="salary", 
    regParam=0.0
)

# %%
# --- FINÁLNÍ PIPELINE ---
# Pořadí v 'stages' je svaté – musí to jít logicky za sebou
pipeline_mine = Pipeline(stages=[
    education_mapping, 
    imputer, 
    indexer, 
    ohe, 
    assembler, 
    scaler,
    model 
    ])

# %% [markdown]
# ### Load features from FS and

# %%
from databricks.feature_store import FeatureLookup

# 1. Definujeme "Levou stranu" (Base)
base_df = spark.table("workspace.default.salary_features").select("id", "salary")

# 2. Definujeme "Pravou stranu" (Lookup / Předpis na Join)
feature_lookups = [
    FeatureLookup(
        table_name="workspace.default.salary_features",
        feature_names=["age", "is_manager", "gender", "experience", "education", "country", "department"],
        lookup_key="id"
    )
]

# 3. Provedeme ten "Join" skrze Feature Store
training_set = fs.create_training_set(
    df=base_df,
    feature_lookups=feature_lookups,
    label="salary",
    exclude_columns=["id"]
)

# 4. Načteme výslednou spojenou tabulku
loaded_fs_table = training_set.load_df()

loaded_fs_table.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>is_manager</th><th>gender</th><th>experience</th><th>education</th><th>country</th><th>department</th><th>salary</th></tr></thead><tbody><tr><td>55</td><td>1</td><td>Male</td><td>28</td><td>PhD</td><td>USA</td><td>IT</td><td>145000.0</td></tr><tr><td>48</td><td>1</td><td>Male</td><td>24</td><td>Master</td><td>USA</td><td>Marketing</td><td>120000.0</td></tr><tr><td>40</td><td>0</td><td>Male</td><td>16</td><td>Master</td><td>Germany</td><td>IT</td><td>88000.0</td></tr><tr><td>32</td><td>0</td><td>Male</td><td>8</td><td>Master</td><td>Germany</td><td>IT</td><td>78000.0</td></tr><tr><td>45</td><td>1</td><td>Female</td><td>21</td><td>Master</td><td>Germany</td><td>Sales</td><td>115000.0</td></tr><tr><td>57</td><td>1</td><td>Male</td><td>30</td><td>PhD</td><td>Germany</td><td>Sales</td><td>150000.0</td></tr><tr><td>30</td><td>0</td><td>Female</td><td>8</td><td>Bachelor</td><td>Germany</td><td>HR</td><td>59000.0</td></tr><tr><td>24</td><td>0</td><td>Male</td><td>6</td><td>Secondary</td><td>Czechia</td><td>Marketing</td><td>41000.0</td></tr><tr><td>29</td><td>0</td><td>Female</td><td>11</td><td>Primary</td><td>Germany</td><td>Sales</td><td>39000.0</td></tr><tr><td>31</td><td>0</td><td>Female</td><td>9</td><td>Bachelor</td><td>Germany</td><td>Marketing</td><td>62000.0</td></tr><tr><td>null</td><td>0</td><td>Female</td><td>11</td><td>Bachelor</td><td>USA</td><td>HR</td><td>64000.0</td></tr><tr><td>44</td><td>1</td><td>Female</td><td>20</td><td>Master</td><td>USA</td><td>IT</td><td>180000.0</td></tr><tr><td>56</td><td>1</td><td>Male</td><td>29</td><td>PhD</td><td>Czechia</td><td>Sales</td><td>149000.0</td></tr><tr><td>null</td><td>0</td><td>Male</td><td>5</td><td>Secondary</td><td>Czechia</td><td>HR</td><td>38000.0</td></tr><tr><td>42</td><td>0</td><td>Female</td><td>18</td><td>Master</td><td>Germany</td><td>IT</td><td>98000.0</td></tr><tr><td>29</td><td>0</td><td>Female</td><td>7</td><td>Bachelor</td><td>Czechia</td><td>HR</td><td>55000.0</td></tr><tr><td>22</td><td>0</td><td>Female</td><td>4</td><td>Primary</td><td>Germany</td><td>IT</td><td>32000.0</td></tr><tr><td>53</td><td>1</td><td>Male</td><td>26</td><td>PhD</td><td>Germany</td><td>Sales</td><td>138000.0</td></tr><tr><td>59</td><td>1</td><td>Male</td><td>32</td><td>PhD</td><td>USA</td><td>Sales</td><td>148000.0</td></tr><tr><td>null</td><td>1</td><td>Male</td><td>24</td><td>PhD</td><td>USA</td><td>Sales</td><td>142000.0</td></tr><tr><td>47</td><td>1</td><td>Male</td><td>25</td><td>Bachelor</td><td>USA</td><td>HR</td><td>105000.0</td></tr><tr><td>null</td><td>0</td><td>Female</td><td>2</td><td>Bachelor</td><td>USA</td><td>IT</td><td>52000.0</td></tr><tr><td>26</td><td>0</td><td>Male</td><td>8</td><td>Secondary</td><td>USA</td><td>Marketing</td><td>49000.0</td></tr><tr><td>43</td><td>0</td><td>Female</td><td>19</td><td>Master</td><td>Czechia</td><td>IT</td><td>92000.0</td></tr><tr><td>35</td><td>0</td><td>Female</td><td>13</td><td>Bachelor</td><td>Germany</td><td>Marketing</td><td>71000.0</td></tr><tr><td>75</td><td>0</td><td>Female</td><td>40</td><td>Secondary</td><td>USA</td><td>HR</td><td>44000.0</td></tr><tr><td>25</td><td>0</td><td>Male</td><td>7</td><td>Secondary</td><td>USA</td><td>Sales</td><td>46000.0</td></tr><tr><td>60</td><td>1</td><td>Male</td><td>33</td><td>PhD</td><td>Czechia</td><td>Sales</td><td>155000.0</td></tr><tr><td>38</td><td>1</td><td>Female</td><td>16</td><td>Bachelor</td><td>Czechia</td><td>Marketing</td><td>85000.0</td></tr><tr><td>28</td><td>0</td><td>Male</td><td>6</td><td>Bachelor</td><td>USA</td><td>IT</td><td>65000.0</td></tr></tbody></table></div>

# %% [markdown]
# ### Train/test split

# %%
# Rozdělení na trénovací (80 %) a testovací (20 %) sadu
# Seed zaručuje, že když kód pustíš znova, dostaneš stejné rozdělení

df_train, df_test = loaded_fs_table.randomSplit([0.8, 0.2], seed=42)

# Jen pro kontrolu, kolik tam toho máme
print(f"Počet řádků v trénovací sadě: {df_train.count()}")
print(f"Počet řádků v testovací sadě: {df_test.count()}")
# Out:
# Počet řádků v trénovací sadě: 22
# Počet řádků v testovací sadě: 8

# %% [markdown]
# ### ML flow

# %% [markdown]
# ##### Enable writing ML flow into Unity catalog

# %%
import os
import mlflow

# Přepne MLflow na Unity Catalog a nastaví dočasnou složku
mlflow.set_registry_uri("databricks-uc")
os.environ['MLFLOW_DFS_TMP'] = f"/Volumes/{DA.catalog_name}/{DA.schema_name}/mlflow_tmp"

# %% [markdown]
# ##### Metrics

# %%
from pyspark.ml.evaluation import RegressionEvaluator
import pyspark.sql.functions as F

# Standardní evaluátory
evaluator_rmse = RegressionEvaluator(labelCol="salary", predictionCol="prediction", metricName="rmse")
evaluator_r2 = RegressionEvaluator(labelCol="salary", predictionCol="prediction", metricName="r2")
evaluator_mae = RegressionEvaluator(labelCol="salary", predictionCol="prediction", metricName="mae")

# %%
from mlflow.models.signature import infer_signature


with mlflow.start_run(run_name="regression_model"):
    
    # 1. Training (Estimator v akci)
    pipeline_model = pipeline_mine.fit(df_train)

    # 2. Prediction (Transformer v akci)
    predictions = pipeline_model.transform(df_test)
    
    # 3. Calculation of metrics
    # Standardní metriky
    rmse = evaluator_rmse.evaluate(predictions)
    r2 = evaluator_r2.evaluate(predictions)
    mae = evaluator_mae.evaluate(predictions)
    
    # mape
    mape = predictions.withColumn("abs_perc_err", F.abs((F.col("salary") - F.col("prediction")) / F.col("salary"))) \
                      .select(F.mean("abs_perc_err") * 100).collect()[0][0]
 
    
    # SIGNATURE Z RAW DAT
    sample_df = df_test.limit(5)
    sample_predictions = pipeline_model.transform(sample_df)

    signature = infer_signature(
        sample_df.drop("salary"), 
        sample_predictions.select("prediction")
    )
    
    # 4. Logging 
    # 4.1. Logging Metrics 
    mlflow.log_metric("rmse", rmse)
    mlflow.log_metric("r2", r2)
    mlflow.log_metric("mae", mae)
    mlflow.log_metric("mape", mape)
    

    # 4.2. Logging pipeline 
    mlflow.spark.log_model(
        spark_model=pipeline_model,
        artifact_path="model",
        signature=signature,           
    )
    
    print(f"Metriky: RMSE: {rmse:.2f}, R2: {r2:.2f}, MAE: {mae:.2f}, MAPE: {mape:.2f}%")

print("Done! Check runs in Experiment!!!")
# Out:
# /databricks/python/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# 2026/04/26 17:12:59 WARNING mlflow.utils.requirements_utils: Found pyspark version (4.1.0+databricks.connect.18.0.2) contains a local version label (+databricks.connect.18.0.2). MLflow logged a pip requirement for this package as 'pyspark==4.1.0' without the local version label to make it installable from PyPI. To specify pip requirements containing local version labels, please use `conda_env` or `pip_requirements`.
# 2026/04/26 17:13:03 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /local_disk0/user_tmp_data/spark-cf1952cb-8e1f-4b98-915f-f9/tmpu3lgrorg/model, flavor: spark). Fall back to return ['pyspark==4.1.0']. Set logging level to DEBUG to see the full traceback.
# Metriky: RMSE: 11393.51, R2: 0.90, MAE: 9686.17, MAPE: 9.96%
# Done! Check runs in Experiment!!!

# %% [markdown]
# ### Metrics

# %%
print(f"rmse: {rmse}")
print(f"mae: {mae}")
print(f"mape: {mape}")
# Out:
# rmse: 11393.510315577503
# mae: 9686.16932027803
# mape: 9.958215794885042

# %% [markdown]
# ### Charts

# %%
import matplotlib.pyplot as plt
import pandas as pd

# 1. Stáhneme data a seřadíme je podle skutečného platu
# Tím vytvoříme plynulou křivku pro srovnání
pdf = predictions.select("salary", "prediction").toPandas()
pdf = pdf.sort_values(by="salary").reset_index(drop=True)

# 2. Vykreslení
plt.figure(figsize=(12, 6))

# Skutečná data (Salary)
plt.plot(pdf.index, pdf["salary"], label="Skutečný plat", color="blue", linewidth=2)

# Predikce (Prediction)
plt.plot(pdf.index, pdf["prediction"], label="Predikce modelu", color="orange", linestyle="--", alpha=0.8)

# Formátování
plt.xlabel("Pořadí testovacích vzorků (seřazeno dle platu)")
plt.ylabel("Plat")
plt.title("Srovnání trendu: Skutečnost vs. Predikce")
plt.legend()
plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# # Inference

# %%
import mlflow

# ID z tvého screenshotu
run_id = "e40f28ad349a493c91306a84da8b5c65"
model_uri = f"runs:/{run_id}/model"

# 1. Načtení
loaded_model = mlflow.pyfunc.load_model(model_uri)

# 2. Příprava dat (bez salary, aby zmizel ten warning)
sample_data = df_test.limit(2).drop("salary").toPandas()

# 3. Predikce
inference = loaded_model.predict(sample_data)

# 4. Výsledek
print(inference)
# Out:
# Downloading artifacts:   0%|          | 0/60 [00:00<?, ?it/s]
# [77927.3650266398, 62061.50094018642]
