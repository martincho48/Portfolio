# %%
#https://www.kaggle.com/code/ursmaheshj/creating-dataset-using-tmdb-api
#https://www.kaggle.com/competitions/tmdb-box-office-prediction/overview
#https://www.kaggle.com/competitions/movie-votes-prediction/overview

# %%
import requests
from dotenv import load_dotenv
import os
import pandas as pd


from time import sleep
from datetime import datetime
from pathlib import Path

# %% [markdown]
# # Define API functions

# %%
def api_upcoming(token, page):

    # Define the path for env is it is in subfolder
    dotenv_path = Path('env/.env')
    load_dotenv(dotenv_path=dotenv_path)

    # Get the credit_id and api_key from environment variables
    bearer_token = os.getenv(token)


    headers = {
        "accept": "application/json",
        "Authorization": f"Bearer {bearer_token}"
    }

    params = {
        'language': 'en-US',
        #'append_to_response': 'credits',
        #'primary_release_date.gte':start_date,
        #'primary_release_date.lte': end_date,
        'page' : page
        }

    url = 'https://api.themoviedb.org/3/movie/upcoming'

    response = requests.get(url, headers=headers, params=params)

    return response

# %%
def api_credits(film_id, key):

    # Define the path for env is it is in subfolder
    dotenv_path = Path('env/.env')
    load_dotenv(dotenv_path=dotenv_path)

    # Get the credit_id and api_key from environment variables
    api_key = os.getenv(key)

    url = f'https://api.themoviedb.org/3/movie/{film_id}?api_key={api_key}&append_to_response=credits'

    response = requests.get(url)

    return response

# %%
def api_credits_loop(input_list: list, key: str, verbose=None) -> pd.DataFrame:

    # Create an empty DataFrame with the required columns
    df = pd.DataFrame(columns=[     'id',
                                    'budget',
                                    'production_companies', 
                                    'production_countries',
                                    'revenue', 
                                    'spoken_languages', 
                                    'genres', 
                                    'runtime',
                                    'tagline',
                                    'crew',
                                    'cast-name'
                                    ])

    counter_to_sleep = 0

    # Assuming df_upcoming is already defined and contains the 'id' column

    for item in input_list:

        try:
            response = api_credits(film_id=item, key=key)
            data = response.json()

        except Exception as err:
            print(f"An error occurred while processing the response: {err}")


        # Create the crew dictionary
        crew_dict = {i.get('job'): i.get('name') for i in data['credits']['crew']}


        # Create the new row with the crew dictionary
        new_row = {
            'id': item,
            'budget': data['budget'],
            'production_companies': [i.get('name') for i in data['production_companies']],
            'production_countries': [i.get('name') for i in data['production_countries']],
            'spoken_languages': [i.get('english_name') for i in data['spoken_languages']],
            'genres': [i.get('name') for i in data['genres']],
            'revenue': data['revenue'],
            'runtime': data['runtime'],
            'tagline': data['tagline'],
            'crew': crew_dict,
            'cast-name': [i.get('name') for i in data['credits']['cast']]
        }

        # Append the new row to the DataFrame
        df.loc[len(df)] = new_row

        counter_to_sleep += 1

        # Sleep after every certain number of iterations
        if counter_to_sleep % 40 == 0:
            sleep(1)


        if verbose ==True:    
            print(counter_to_sleep)
        
    return df

# %% [markdown]
# # Get data - Upcoming films

# %%
# We will first create an empty dataframe to store all the movie detail
df_upcoming = pd.DataFrame()

page_counter = 1

while True:

        response = api_upcoming(        token='BEARER_TOKEN', 
                                        page=page_counter
                                        )
        

        temporary_df = pd.DataFrame(response.json()['results'])

        if not temporary_df.empty:
                df_upcoming = pd.concat([df_upcoming, temporary_df],ignore_index=True)
       
        else:
                break

        # Increment the page number and sleep counter
        page_counter += 1
        
        # Sleep after every certain number of iterations
        if page_counter%40==0: sleep(1)

# %%
df_upcoming.head(1)
# Out:
#    adult                     backdrop_path         genre_ids      id  \
# 0  False  /ga4OLm4qLxPqKLMzjJlqHxVjst3.jpg  [28, 80, 53, 35]  573435
#
#   original_language         original_title  \
# 0                en  Bad Boys: Ride or Die
#
#                                             overview  popularity  \
# 0  After their late former Captain is framed, Low...    2585.897
#
#                         poster_path release_date                  title  \
# 0  /nP6RliHjxsz4irTKsxe8FRhKZYl.jpg   2024-06-05  Bad Boys: Ride or Die
#
#    video  vote_average  vote_count
# 0  False           7.2         172

# %%
df_upcoming.shape
# Out:
# (719, 14)

# %%
df_upcoming.to_csv('output/df_upcoming.csv')

# %% [markdown]
# # Get data - Credits

# %% [markdown]
# ### Get list if ids

# %%
# Get the list of ids needed for API credits
id_list = df_upcoming['id'].to_list()
id_list[:5]
# Out:
# [573435, 1022789, 974635, 882059, 748783]

# %% [markdown]
# ### Call function

# %%
df_credits = api_credits_loop(      input_list = id_list,
                                    key='API_KEY',
                    )
df_credits
# Out:
#           id     budget                               production_companies  \
# 0     573435   80000000  [Westbrook Studios, Columbia Pictures, Don Sim...
# 1    1022789  200000000                      [Pixar, Walt Disney Pictures]
# 2     974635    8800000  [Aggregate Films, BarnStorm Productions, Detou...
# 3     882059   18000000  [Vertigo Entertainment, Hammerstone Studios, N...
# 4     748783   60000000  [Alcon Entertainment, Prime Focus, DNEG Animat...
# ..       ...        ...                                                ...
# 714  1303677          0                                     [Oz Produtora]
# 715  1303655          0                                                 []
# 716  1303649          0                                                 []
# 717  1303578          0                                                 []
# 718  1303578          0                                                 []
#
#                                   production_countries    revenue  \
# 0                           [United States of America]  104600000
# 1                           [United States of America]          0
# 2                           [United States of America]    1139025
# 3                           [United States of America]    3139717
# 4    [Hong Kong, India, United Kingdom, United Stat...  192713000
# ..                                                 ...        ...
# 714                                           [Brazil]          0
# 715                                                 []          0
# 716                                                 []          0
# 717                                                 []          0
# 718                                                 []          0
#
#     spoken_languages                                         genres  runtime  \
# 0          [English]              [Action, Crime, Thriller, Comedy]      115
# 1          [English]  [Animation, Family, Drama, Adventure, Comedy]       97
# 2          [English]                       [Romance, Comedy, Crime]      116
# 3          [English]     [Action, Thriller, Crime, Science Fiction]      110
# 4          [English]         [Animation, Comedy, Family, Adventure]      101
# ..               ...                                            ...      ...
# 714     [Portuguese]                                    [Animation]        4
# 715               []                                  [Documentary]        0
# 716               []                                             []       37
# 717         [German]                                             []        0
# 718         [German]                                             []        0
#
#                                      tagline  \
# 0    Miami's finest are now its most wanted.
# 1                Make room for new emotions.
# 2     He's not a killer, but he can pretend.
# 3
# 4             Indoor cat. Outdoor adventure.
# ..                                       ...
# 714
# 715
# 716
# 717
# 718
#
#                                                   crew  \
# 0    {'Producer': 'Chad Oman', 'Characters': 'Georg...
# 1    {'Director': 'Kelsey Mann', 'Producer': 'Mark ...
# 2    {'Director': 'Richard Linklater', 'Producer': ...
# 3    {'Director': 'Moritz Mohr', 'Producer': 'Simon...
# 4    {'Storyboard Artist': 'Bob Scott', 'Production...
# ..                                                 ...
# 714  {'Director': 'Hygor Amorim', 'Producer': 'Aman...
# 715                                                 {}
# 716                    {'Director': 'Nataliya Ilchuk'}
# 717                                                 {}
# 718                                                 {}
#
#                                              cast-name
# 0    [Will Smith, Martin Lawrence, Vanessa Hudgens,...
# 1    [Amy Poehler, Maya Hawke, Kensington Tallman, ...
# 2    [Glen Powell, Adria Arjona, Austin Amelio, Ret...
# 3    [Bill Skarsgård, Jessica Rothe, Michelle Docke...
# 4    [Chris Pratt, Samuel L. Jackson, Hannah Waddin...
# ..                                                 ...
# 714                                                 []
# 715                                                 []
# 716                                [Khrystyna Savchuk]
# 717                                                 []
# 718                                                 []
#
# [719 rows x 11 columns]

# %%
df_credits.head(5)
# Out:
#         id     budget                               production_companies  \
# 0   573435   80000000  [Westbrook Studios, Columbia Pictures, Don Sim...
# 1  1022789  200000000                      [Pixar, Walt Disney Pictures]
# 2   974635    8800000  [Aggregate Films, BarnStorm Productions, Detou...
# 3   882059   18000000  [Vertigo Entertainment, Hammerstone Studios, N...
# 4   748783   60000000  [Alcon Entertainment, Prime Focus, DNEG Animat...
#
#                                 production_countries    revenue  \
# 0                         [United States of America]  104600000
# 1                         [United States of America]          0
# 2                         [United States of America]    1139025
# 3                         [United States of America]    3139717
# 4  [Hong Kong, India, United Kingdom, United Stat...  192713000
#
#   spoken_languages                                         genres  runtime  \
# 0        [English]              [Action, Crime, Thriller, Comedy]      115
# 1        [English]  [Animation, Family, Drama, Adventure, Comedy]       97
# 2        [English]                       [Romance, Comedy, Crime]      116
# 3        [English]     [Action, Thriller, Crime, Science Fiction]      110
# 4        [English]         [Animation, Comedy, Family, Adventure]      101
#
#                                    tagline  \
# 0  Miami's finest are now its most wanted.
# 1              Make room for new emotions.
# 2   He's not a killer, but he can pretend.
# 3
# 4           Indoor cat. Outdoor adventure.
#
#                                                 crew  \
# 0  {'Producer': 'Chad Oman', 'Characters': 'Georg...
# 1  {'Director': 'Kelsey Mann', 'Producer': 'Mark ...
# 2  {'Director': 'Richard Linklater', 'Producer': ...
# 3  {'Director': 'Moritz Mohr', 'Producer': 'Simon...
# 4  {'Storyboard Artist': 'Bob Scott', 'Production...
#
#                                            cast-name
# 0  [Will Smith, Martin Lawrence, Vanessa Hudgens,...
# 1  [Amy Poehler, Maya Hawke, Kensington Tallman, ...
# 2  [Glen Powell, Adria Arjona, Austin Amelio, Ret...
# 3  [Bill Skarsgård, Jessica Rothe, Michelle Docke...
# 4  [Chris Pratt, Samuel L. Jackson, Hannah Waddin...

# %%
df_credits.shape
# Out:
# (719, 11)

# %% [markdown]
# # Save data

# %%
df_credits.to_csv('output/df_credits.csv', index=False)
