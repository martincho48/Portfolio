# %%
import pandas as pd
import ast
import json
import numpy as np

import re

# %% [markdown]
# # Read dataframes

# %%
df_upcoming = pd.read_csv('output/df_upcoming.csv', index_col=0)
df_upcoming.tail(5)
# Out:
#      adult backdrop_path genre_ids       id original_language  \
# 714  False           NaN      [16]  1303677                pt
# 715  False           NaN      [99]  1303655                en
# 716  False           NaN        []  1303649                uk
# 717  False           NaN        []  1303578                de
# 718  False           NaN        []  1303578                de
#
#                              original_title  \
# 714  Mytikah Explora – Maria Sibylla Merian
# 715                     Breakin' on the One
# 716                                Clubbing
# 717       Die Drei ??? -Das Dorf der Teufel
# 718       Die Drei ??? -Das Dorf der Teufel
#
#                                               overview  popularity  \
# 714  Manga and Leco learn about the story Maria Sib...         1.4
# 715  In 1981, a breaking battle between the Rockste...         1.4
# 716  The film is about the constraints faced by two...         1.4
# 717  Radio play in 3D sound = cinema for your ears!...         1.4
# 718  Radio play in 3D sound = cinema for your ears!...         1.4
#
#                           poster_path release_date  \
# 714  /6CfCoS3O1pZUKXip6QdRwbXlbJt.jpg   2024-06-19
# 715                               NaN   2024-06-24
# 716  /wFyirnWB4NaPctJqhY3PFVVH4RV.jpg   2024-06-26
# 717  /bhHs1BDN6zrAkODWxokyl2hbqXI.jpg   2024-06-27
# 718  /bhHs1BDN6zrAkODWxokyl2hbqXI.jpg   2024-06-27
#
#                                       title  video  vote_average  vote_count
# 714  Mytikah Explora – Maria Sibylla Merian  False           0.0           0
# 715                     Breakin' on the One  False           0.0           0
# 716                                Clubbing  False           0.0           0
# 717       Die Drei ??? -Das Dorf der Teufel  False           0.0           0
# 718       Die Drei ??? -Das Dorf der Teufel  False           0.0           0

# %%
# Read the CSV file with the converter function
df_credits = pd.read_csv('output/df_credits.csv')

df_credits.head(2)
# Out:
#         id     budget                               production_companies  \
# 0   573435   80000000  ['Westbrook Studios', 'Columbia Pictures', 'Do...
# 1  1022789  200000000                  ['Pixar', 'Walt Disney Pictures']
#
#            production_countries    revenue spoken_languages  \
# 0  ['United States of America']  104600000      ['English']
# 1  ['United States of America']          0      ['English']
#
#                                               genres  runtime  \
# 0          ['Action', 'Crime', 'Thriller', 'Comedy']      115
# 1  ['Animation', 'Family', 'Drama', 'Adventure', ...       97
#
#                                    tagline  \
# 0  Miami's finest are now its most wanted.
# 1              Make room for new emotions.
#
#                                                 crew  \
# 0  {'Producer': 'Chad Oman', 'Characters': 'Georg...
# 1  {'Director': 'Kelsey Mann', 'Producer': 'Mark ...
#
#                                            cast-name
# 0  ['Will Smith', 'Martin Lawrence', 'Vanessa Hud...
# 1  ['Amy Poehler', 'Maya Hawke', 'Kensington Tall...

# %% [markdown]
# # Create extra columns

# %% [markdown]
# ## Evaluate dtypes

# %%
# Function that safely evaluates a string representation of a literal Python expression and returns the corresponding Python object

list_items = ['spoken_languages','genres', 'cast-name', 'production_companies', 'crew', 'production_countries']

for item in list_items:

    df_credits[item] = df_credits[item].apply(ast.literal_eval)

# %% [markdown]
# ## Define functions

# %% [markdown]
# ### From dictionaries

# %%
# Define the function
def add_col_dict(df, new_col_name, searched_item, searched_col_name):
    add_col = [key.get(searched_item, np.nan) for key in df[searched_col_name]]
    df[new_col_name] = add_col

# %% [markdown]
# ### From list - 2 items

# %%
# Define a function to extract the first and second items from a list
def extract_2_items(actor_list):
    return actor_list[:2] if actor_list else [None, None]


def add_2_items_list(df, new_col_name1, new_col_name2, source_col_name):
    # Apply the function using a list comprehension to create two new columns
    df[[new_col_name1, new_col_name2]] = pd.DataFrame(df[source_col_name].apply(extract_2_items).tolist(), index=df.index)

# %% [markdown]
# ### From list - 1 item

# %%
# Define a function to extract the first item from a list
def extract_1_item(actor_list):
    return actor_list[:1] if actor_list else [None]


def add_1_item_list(df, new_col_name1, source_col_name):
    # Apply the function using a list comprehension to create two new columns
    df[[new_col_name1]] = pd.DataFrame(df[source_col_name].apply(extract_1_item).tolist(), index=df.index)

# %% [markdown]
# ### Call functions

# %%
# Call the function 

add_col_dict(df=df_credits, 
        new_col_name='director', 
        searched_item='Director', 
        searched_col_name='crew'
        )


add_col_dict(df=df_credits, 
        new_col_name='producer', 
        searched_item='Producer', 
        searched_col_name='crew'
        )

add_col_dict(df=df_credits, 
        new_col_name='sound', 
        searched_item='Original Music Composer', 
        searched_col_name='crew'
        )

add_col_dict(df=df_credits, 
        new_col_name='camera', 
        searched_item='Director of Photography', 
        searched_col_name='crew'
        )


add_col_dict(df=df_credits, 
        new_col_name='screenplay', 
        searched_item='Screenplay', 
        searched_col_name='crew'
        )


df_credits.head(2)
# Out:
#         id     budget                               production_companies  \
# 0   573435   80000000  [Westbrook Studios, Columbia Pictures, Don Sim...
# 1  1022789  200000000                      [Pixar, Walt Disney Pictures]
#
#          production_countries    revenue spoken_languages  \
# 0  [United States of America]  104600000        [English]
# 1  [United States of America]          0        [English]
#
#                                           genres  runtime  \
# 0              [Action, Crime, Thriller, Comedy]      115
# 1  [Animation, Family, Drama, Adventure, Comedy]       97
#
#                                    tagline  \
# 0  Miami's finest are now its most wanted.
# 1              Make room for new emotions.
#
#                                                 crew  \
# 0  {'Producer': 'Chad Oman', 'Characters': 'Georg...
# 1  {'Director': 'Kelsey Mann', 'Producer': 'Mark ...
#
#                                            cast-name       director  \
# 0  [Will Smith, Martin Lawrence, Vanessa Hudgens,...  Bilall Fallah
# 1  [Amy Poehler, Maya Hawke, Kensington Tallman, ...    Kelsey Mann
#
#        producer           sound             camera     screenplay
# 0     Chad Oman     Lorne Balfe  Robrecht Heyvaert            NaN
# 1  Mark Nielsen  Andrea Datzman     Jonathan Pytko  Dave Holstein

# %%
add_2_items_list(df=df_credits, 
            new_col_name1='actor1', 
            new_col_name2='actor2', 
            source_col_name='cast-name'
            )

# %%
df_credits.head(2)
# Out:
#         id     budget                               production_companies  \
# 0   573435   80000000  [Westbrook Studios, Columbia Pictures, Don Sim...
# 1  1022789  200000000                      [Pixar, Walt Disney Pictures]
#
#          production_countries    revenue spoken_languages  \
# 0  [United States of America]  104600000        [English]
# 1  [United States of America]          0        [English]
#
#                                           genres  runtime  \
# 0              [Action, Crime, Thriller, Comedy]      115
# 1  [Animation, Family, Drama, Adventure, Comedy]       97
#
#                                    tagline  \
# 0  Miami's finest are now its most wanted.
# 1              Make room for new emotions.
#
#                                                 crew  \
# 0  {'Producer': 'Chad Oman', 'Characters': 'Georg...
# 1  {'Director': 'Kelsey Mann', 'Producer': 'Mark ...
#
#                                            cast-name       director  \
# 0  [Will Smith, Martin Lawrence, Vanessa Hudgens,...  Bilall Fallah
# 1  [Amy Poehler, Maya Hawke, Kensington Tallman, ...    Kelsey Mann
#
#        producer           sound             camera     screenplay  \
# 0     Chad Oman     Lorne Balfe  Robrecht Heyvaert            NaN
# 1  Mark Nielsen  Andrea Datzman     Jonathan Pytko  Dave Holstein
#
#         actor1           actor2
# 0   Will Smith  Martin Lawrence
# 1  Amy Poehler       Maya Hawke

# %%
add_1_item_list(df=df_credits, 
            new_col_name1='production_company', 
            source_col_name='production_companies'
            )


add_1_item_list(df=df_credits, 
            new_col_name1='production_country', 
            source_col_name='production_countries'
            )


add_1_item_list(df=df_credits, 
            new_col_name1='genre', 
            source_col_name='genres'
            )


""" add_1_item_list(df=df_credits, 
            new_col_name1='spoken_language', 
            source_col_name='spoken_languages'
            ) """
# Out:
# " add_1_item_list(df=df_credits, \n            new_col_name1='spoken_language', \n            source_col_name='spoken_languages'\n            ) "

# %%
df_credits.head(5)
# Out:
#         id     budget                               production_companies  \
# 0   573435   80000000  [Westbrook Studios, Columbia Pictures, Don Sim...
# 1  1022789  200000000                      [Pixar, Walt Disney Pictures]
# 2   974635    8800000  [Aggregate Films, BarnStorm Productions, Detou...
# 3   882059   18000000  [Vertigo Entertainment, Hammerstone Studios, N...
# 4   748783   60000000  [Alcon Entertainment, Prime Focus, DNEG Animat...
#
#                                 production_countries    revenue  \
# 0                         [United States of America]  104600000
# 1                         [United States of America]          0
# 2                         [United States of America]    1139025
# 3                         [United States of America]    3139717
# 4  [Hong Kong, India, United Kingdom, United Stat...  192713000
#
#   spoken_languages                                         genres  runtime  \
# 0        [English]              [Action, Crime, Thriller, Comedy]      115
# 1        [English]  [Animation, Family, Drama, Adventure, Comedy]       97
# 2        [English]                       [Romance, Comedy, Crime]      116
# 3        [English]     [Action, Thriller, Crime, Science Fiction]      110
# 4        [English]         [Animation, Comedy, Family, Adventure]      101
#
#                                    tagline  \
# 0  Miami's finest are now its most wanted.
# 1              Make room for new emotions.
# 2   He's not a killer, but he can pretend.
# 3                                      NaN
# 4           Indoor cat. Outdoor adventure.
#
#                                                 crew  ...           director  \
# 0  {'Producer': 'Chad Oman', 'Characters': 'Georg...  ...      Bilall Fallah
# 1  {'Director': 'Kelsey Mann', 'Producer': 'Mark ...  ...        Kelsey Mann
# 2  {'Director': 'Richard Linklater', 'Producer': ...  ...  Richard Linklater
# 3  {'Director': 'Moritz Mohr', 'Producer': 'Simon...  ...        Moritz Mohr
# 4  {'Storyboard Artist': 'Bob Scott', 'Production...  ...        Mark Dindal
#
#         producer            sound             camera      screenplay  \
# 0      Chad Oman      Lorne Balfe  Robrecht Heyvaert             NaN
# 1   Mark Nielsen   Andrea Datzman     Jonathan Pytko   Dave Holstein
# 2  Mike Blizzard  Graham Reynolds     Shane F. Kelly     Glen Powell
# 3    Simon Swart  Ludvig Forssell     Peter Matjasko             NaN
# 4     Craig Sost      John Debney                NaN  Paul A. Kaplan
#
#            actor1             actor2     production_company  \
# 0      Will Smith    Martin Lawrence      Westbrook Studios
# 1     Amy Poehler         Maya Hawke                  Pixar
# 2     Glen Powell       Adria Arjona        Aggregate Films
# 3  Bill Skarsgård      Jessica Rothe  Vertigo Entertainment
# 4     Chris Pratt  Samuel L. Jackson    Alcon Entertainment
#
#          production_country      genre
# 0  United States of America     Action
# 1  United States of America  Animation
# 2  United States of America    Romance
# 3  United States of America     Action
# 4                 Hong Kong  Animation
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Drop cols used for parsing

# %%
df_credits = df_credits.drop(columns=list_items)
df_credits.head(5)
# Out:
#         id     budget    revenue  runtime  \
# 0   573435   80000000  104600000      115
# 1  1022789  200000000          0       97
# 2   974635    8800000    1139025      116
# 3   882059   18000000    3139717      110
# 4   748783   60000000  192713000      101
#
#                                    tagline           director       producer  \
# 0  Miami's finest are now its most wanted.      Bilall Fallah      Chad Oman
# 1              Make room for new emotions.        Kelsey Mann   Mark Nielsen
# 2   He's not a killer, but he can pretend.  Richard Linklater  Mike Blizzard
# 3                                      NaN        Moritz Mohr    Simon Swart
# 4           Indoor cat. Outdoor adventure.        Mark Dindal     Craig Sost
#
#              sound             camera      screenplay          actor1  \
# 0      Lorne Balfe  Robrecht Heyvaert             NaN      Will Smith
# 1   Andrea Datzman     Jonathan Pytko   Dave Holstein     Amy Poehler
# 2  Graham Reynolds     Shane F. Kelly     Glen Powell     Glen Powell
# 3  Ludvig Forssell     Peter Matjasko             NaN  Bill Skarsgård
# 4      John Debney                NaN  Paul A. Kaplan     Chris Pratt
#
#               actor2     production_company        production_country  \
# 0    Martin Lawrence      Westbrook Studios  United States of America
# 1         Maya Hawke                  Pixar  United States of America
# 2       Adria Arjona        Aggregate Films  United States of America
# 3      Jessica Rothe  Vertigo Entertainment  United States of America
# 4  Samuel L. Jackson    Alcon Entertainment                 Hong Kong
#
#        genre
# 0     Action
# 1  Animation
# 2    Romance
# 3     Action
# 4  Animation

# %% [markdown]
# # Merge

# %%
df_merged = pd.merge(df_upcoming,df_credits, on='id')
df_merged.head(2)
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /ga4OLm4qLxPqKLMzjJlqHxVjst3.jpg         [28, 80, 53, 35]   573435
# 1  False  /qjoX7hl721FOiyeHsDkeQ6rFVLl.jpg  [16, 10751, 18, 12, 35]  1022789
#
#   original_language         original_title  \
# 0                en  Bad Boys: Ride or Die
# 1                en           Inside Out 2
#
#                                             overview  popularity  \
# 0  After their late former Captain is framed, Low...    2585.897
# 1  Teenager Riley's mind headquarters is undergoi...    1813.010
#
#                         poster_path release_date  ...       director  \
# 0  /nP6RliHjxsz4irTKsxe8FRhKZYl.jpg   2024-06-05  ...  Bilall Fallah
# 1  /vpnVM9B6NMmQpWeZvzLvDESb2QY.jpg   2024-06-11  ...    Kelsey Mann
#
#        producer           sound             camera     screenplay  \
# 0     Chad Oman     Lorne Balfe  Robrecht Heyvaert            NaN
# 1  Mark Nielsen  Andrea Datzman     Jonathan Pytko  Dave Holstein
#
#         actor1           actor2 production_company        production_country  \
# 0   Will Smith  Martin Lawrence  Westbrook Studios  United States of America
# 1  Amy Poehler       Maya Hawke              Pixar  United States of America
#
#        genre
# 0     Action
# 1  Animation
#
# [2 rows x 28 columns]

# %% [markdown]
# # Drop Columns with many NaN

# %%
df_merged.isna().sum()
# Out:
# adult                   0
# backdrop_path         362
# genre_ids               0
# id                      0
# original_language       0
# original_title          0
# overview               66
# popularity              0
# poster_path           129
# release_date            2
# title                   0
# video                   0
# vote_average            0
# vote_count              0
# budget                  0
# revenue                 0
# runtime                 0
# tagline               538
# director               41
# producer              289
# sound                 614
# camera                416
# screenplay            599
# actor1                136
# actor2                180
# production_company    246
# production_country    216
# genre                 126
# dtype: int64

# %%
df_merged = df_merged.drop(columns=['backdrop_path', 'poster_path', 'tagline', 'overview', 'sound', 'screenplay', 'camera', 'producer'])
df_merged.head(5)
# Out:
#    adult                genre_ids       id original_language  \
# 0  False         [28, 80, 53, 35]   573435                en
# 1  False  [16, 10751, 18, 12, 35]  1022789                en
# 2  False          [10749, 35, 80]   974635                en
# 3  False        [28, 53, 80, 878]   882059                en
# 4  False      [16, 35, 10751, 12]   748783                en
#
#           original_title  popularity release_date                  title  \
# 0  Bad Boys: Ride or Die    2585.897   2024-06-05  Bad Boys: Ride or Die
# 1           Inside Out 2    1813.010   2024-06-11           Inside Out 2
# 2                Hit Man     888.899   2024-05-16                Hit Man
# 3        Boy Kills World     433.026   2024-04-24        Boy Kills World
# 4     The Garfield Movie     502.943   2024-04-30     The Garfield Movie
#
#    video  vote_average  vote_count     budget    revenue  runtime  \
# 0  False         7.200         172   80000000  104600000      115
# 1  False         7.581          31  200000000          0       97
# 2  False         6.900         199    8800000    1139025      116
# 3  False         6.906         272   18000000    3139717      110
# 4  False         6.420         157   60000000  192713000      101
#
#             director          actor1             actor2  \
# 0      Bilall Fallah      Will Smith    Martin Lawrence
# 1        Kelsey Mann     Amy Poehler         Maya Hawke
# 2  Richard Linklater     Glen Powell       Adria Arjona
# 3        Moritz Mohr  Bill Skarsgård      Jessica Rothe
# 4        Mark Dindal     Chris Pratt  Samuel L. Jackson
#
#       production_company        production_country      genre
# 0      Westbrook Studios  United States of America     Action
# 1                  Pixar  United States of America  Animation
# 2        Aggregate Films  United States of America    Romance
# 3  Vertigo Entertainment  United States of America     Action
# 4    Alcon Entertainment                 Hong Kong  Animation

# %%
df_merged.isna().sum()
# Out:
# adult                   0
# genre_ids               0
# id                      0
# original_language       0
# original_title          0
# popularity              0
# release_date            2
# title                   0
# video                   0
# vote_average            0
# vote_count              0
# budget                  0
# revenue                 0
# runtime                 0
# director               41
# actor1                136
# actor2                180
# production_company    246
# production_country    216
# genre                 126
# dtype: int64

# %% [markdown]
# # Drop useless Columns

# %%
df_merged = df_merged.drop(columns=['genre_ids', 'video', 'adult','original_title'])

# %% [markdown]
# # Drop Rows with NaN

# %%
# Drop all rows which contain any NaN values
df_merged= df_merged.dropna()

# %%
df_merged.isna().sum()
# Out:
# id                    0
# original_language     0
# popularity            0
# release_date          0
# title                 0
# vote_average          0
# vote_count            0
# budget                0
# revenue               0
# runtime               0
# director              0
# actor1                0
# actor2                0
# production_company    0
# production_country    0
# genre                 0
# dtype: int64

# %%
df_merged.shape
# Out:
# (363, 16)

# %% [markdown]
# # Final adjustment

# %%
cut = df_merged[df_merged['runtime']==0]
cut
# Out:
#           id original_language  popularity release_date               title  \
# 8    1093995                en     303.245   2024-05-02    Chief of Station
# 55   1215918                en      24.725   2024-06-21     Blackwater Lane
# 59   1291436                tl      32.556   2024-06-28               Huwad
# 60   1291436                tl      32.556   2024-06-28               Huwad
# 61   1291436                tl      32.556   2024-06-28               Huwad
# ..       ...               ...         ...          ...                 ...
# 605  1246372                es       2.118   2023-09-29     In Another Life
# 612  1299288                tr       2.047   2024-06-28      La Hayde Maske
# 640  1195360                zh       1.859   2024-07-05  Welcome to My Side
# 673  1302332                it       1.058   2024-06-19             Camilla
# 685   874763                ml       0.515   2024-06-21         Gaganachari
#
#      vote_average  vote_count  budget  revenue  runtime          director  \
# 8           5.272          46       0        0        0  Jesse V. Johnson
# 55          0.000           0       0        0        0    Jeff Celentano
# 59          0.000           0       0        0        0      Reynold Giba
# 60          0.000           0       0        0        0      Reynold Giba
# 61          0.000           0       0        0        0      Reynold Giba
# ..            ...         ...     ...      ...      ...               ...
# 605        10.000           1     600        0        0        Kaory Rios
# 612         0.000           0       0        0        0      Sefa Özçelik
# 640         0.000           0       0        0        0       Song Haolin
# 673         0.000           0    3000        0        0     Tommaso Barba
# 685         0.000           0       0        0        0       Arun Chandu
#
#               actor1              actor2            production_company  \
# 8      Aaron Eckhart       Alex Pettyfer        Bee Holder Productions
# 55   Dermot Mulroney         Minka Kelly  Clear Pictures Entertainment
# 59        Azi Acosta       Aerol Carmelo                       Vivamax
# 60        Azi Acosta       Aerol Carmelo                       Vivamax
# 61        Azi Acosta       Aerol Carmelo                       Vivamax
# ..               ...                 ...                           ...
# 605    Andrea Rivera  Daniel Villalpando                         UPAEP
# 612        Ayhan Taş       Burak Satıbol                 SineLine Film
# 640           Yu Shi         Wang Yinglu                  海南可能制造影业有限公司
# 673   Beatrice Gatta       Antonio Greco            Accademia Griffith
# 685     Gokul Suresh        Aju Varghese  Ajith Vinayaka Films Pvt Ltd
#
#            production_country            genre
# 8    United States of America           Action
# 55   United States of America         Thriller
# 59                Philippines            Drama
# 60                Philippines            Drama
# 61                Philippines            Drama
# ..                        ...              ...
# 605                    Mexico            Drama
# 612                    Turkey           Comedy
# 640                     China           Comedy
# 673                     Italy            Drama
# 685                     India  Science Fiction
#
# [82 rows x 16 columns]

# %%
df_merged = df_merged[df_merged['runtime']>=60]
df_merged.shape
# Out:
# (257, 16)

# %% [markdown]
# # Remove duplicates

# %%
df_merged = df_merged.drop_duplicates()
df_merged.shape
# Out:
# (257, 16)

# %% [markdown]
# # Save df

# %%
df_merged.to_csv('output/cleaned-upcoming-test.csv')
